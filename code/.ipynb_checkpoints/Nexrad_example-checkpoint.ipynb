# %%
from siphon.radarserver import RadarServer
from datetime import datetime, timedelta
import numpy as np
import metpy.plots as mpplots
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import gzip

# %%
def get_gzip(gzfile):
    with gzip.open(gzfile, 'r') as pf:
        file_content = pf.read()
    print(file_content)

# %%
rs = RadarServer('http://tds-nexrad.scigw.unidata.ucar.edu/thredds/radarServer/nexrad/level2/S3/')

# %%
query = rs.query()
query.stations('KLVX').time(datetime.utcnow())
# Out:
# time=2021-06-26T13%3A57%3A20.133317&stn=KLVX

# %%
rs.validate_query(query)
# Out:
# True

# %%
catalog = rs.get_catalog(query)

# %%
catalog.datasets[0]
# Out:
# ['KLVX20210626_134626_V06']

# %%
get_gzip(catalog.datasets[0])
# Out:
# -------------------------------------------------------------------------
# TypeError                               Traceback (most recent call last)
# <ipython-input-21-62c1e5662147> in <module>
# ----> 1 get_gzip(catalog.datasets[0])
#
# <ipython-input-13-df0a20ecb4a3> in get_gzip(gzfile)
#       1 def get_gzip(gzfile):
# ----> 2     with gzip.open(gzfile, 'r') as pf:
#       3         file_content = pf.read()
#       4     print(file_content)
#
# ~/opt/anaconda3/lib/python3.8/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      60         binary_file = GzipFile(None, gz_mode, compresslevel, filename)
#      61     else:
# ---> 62         raise TypeError("filename must be a str or bytes object, or a file")
#      63
#      64     if "t" in mode:
#
# TypeError: filename must be a str or bytes object, or a file

# %%
data = catalog.datasets[0].remote_access()

# %%
data
# Out:
# http://tds-nexrad.scigw.unidata.ucar.edu/thredds/cdmremote/nexrad/level2/S3/2021/06/26/KLVX/KLVX20210626_133647_V06
# Dimensions:
# <class 'siphon.cdmr.dataset.Dimension'> name = scanR_HI, size = 4
# <class 'siphon.cdmr.dataset.Dimension'> name = gateR_HI, size = 1832
# <class 'siphon.cdmr.dataset.Dimension'> name = radialR_HI, size = 720
# <class 'siphon.cdmr.dataset.Dimension'> name = scanR, size = 3
# <class 'siphon.cdmr.dataset.Dimension'> name = gateR, size = 1324
# <class 'siphon.cdmr.dataset.Dimension'> name = radialR, size = 360
# <class 'siphon.cdmr.dataset.Dimension'> name = scanV_HI, size = 2
# <class 'siphon.cdmr.dataset.Dimension'> name = gateV_HI, size = 1192
# <class 'siphon.cdmr.dataset.Dimension'> name = radialV_HI, size = 720
# <class 'siphon.cdmr.dataset.Dimension'> name = scanV, size = 3
# <class 'siphon.cdmr.dataset.Dimension'> name = gateV, size = 1192
# <class 'siphon.cdmr.dataset.Dimension'> name = radialV, size = 360
# <class 'siphon.cdmr.dataset.Dimension'> name = scanD_HI, size = 2
# <class 'siphon.cdmr.dataset.Dimension'> name = gateD_HI, size = 1192
# <class 'siphon.cdmr.dataset.Dimension'> name = radialD_HI, size = 720
# <class 'siphon.cdmr.dataset.Dimension'> name = scanD, size = 3
# <class 'siphon.cdmr.dataset.Dimension'> name = gateD, size = 1192
# <class 'siphon.cdmr.dataset.Dimension'> name = radialD, size = 360
# <class 'siphon.cdmr.dataset.Dimension'> name = scanC_HI, size = 2
# <class 'siphon.cdmr.dataset.Dimension'> name = gateC_HI, size = 1192
# <class 'siphon.cdmr.dataset.Dimension'> name = radialC_HI, size = 720
# <class 'siphon.cdmr.dataset.Dimension'> name = scanC, size = 3
# <class 'siphon.cdmr.dataset.Dimension'> name = gateC, size = 1192
# <class 'siphon.cdmr.dataset.Dimension'> name = radialC, size = 360
# <class 'siphon.cdmr.dataset.Dimension'> name = scanP_HI, size = 2
# <class 'siphon.cdmr.dataset.Dimension'> name = gateP_HI, size = 1192
# <class 'siphon.cdmr.dataset.Dimension'> name = radialP_HI, size = 720
# <class 'siphon.cdmr.dataset.Dimension'> name = scanP, size = 3
# <class 'siphon.cdmr.dataset.Dimension'> name = gateP, size = 1192
# <class 'siphon.cdmr.dataset.Dimension'> name = radialP, size = 360
# Variables:
# <class 'siphon.cdmr.dataset.Variable'>
# int8 Reflectivity_HI(scanR_HI, radialR_HI, gateR_HI)
# 	units: dBz
# 	long_name: Reflectivity_HI
# 	missing_value: [1 0]
# 	signal_below_threshold: 0
# 	scale_factor: 0.5
# 	add_offset: -33.0
# 	_Unsigned: true
# 	SNR_threshold: 4
# 	range_folding_threshold: 50
# 	_CoordinateAxes: timeR_HI elevationR_HI azimuthR_HI distanceR_HI
# shape = (4, 720, 1832)
# <class 'siphon.cdmr.dataset.Variable'>
# int32 timeR_HI(scanR_HI, radialR_HI)
# 	long_name: time of each ray
# 	units: msecs since 2021-06-26T00:00:00Z
# 	missing_value: -9999
# 	_CoordinateAxisType: Time
# shape = (4, 720)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 elevationR_HI(scanR_HI, radialR_HI)
# 	units: degrees
# 	long_name: elevation angle in degres: 0 = parallel to pedestal base, 90 = perpendicular
# 	missing_value: nan
# 	_CoordinateAxisType: RadialElevation
# shape = (4, 720)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 azimuthR_HI(scanR_HI, radialR_HI)
# 	units: degrees
# 	long_name: azimuth angle in degrees: 0 = true north, 90 = east
# 	missing_value: nan
# 	_CoordinateAxisType: RadialAzimuth
# shape = (4, 720)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 distanceR_HI(gateR_HI)
# 	units: m
# 	long_name: radial distance to start of gate
# 	_CoordinateAxisType: RadialDistance
# shape = 1832
# <class 'siphon.cdmr.dataset.Variable'>
# int32 numRadialsR_HI(scanR_HI)
# 	long_name: number of valid radials in this scan
# shape = 4
# <class 'siphon.cdmr.dataset.Variable'>
# int32 numGatesR_HI(scanR_HI)
# 	long_name: number of valid gates in this scan
# shape = 4
# <class 'siphon.cdmr.dataset.Variable'>
# int8 Reflectivity(scanR, radialR, gateR)
# 	units: dBz
# 	long_name: Reflectivity
# 	missing_value: [1 0]
# 	signal_below_threshold: 0
# 	scale_factor: 0.5
# 	add_offset: -33.0
# 	_Unsigned: true
# 	range_folding_threshold: 50
# 	_CoordinateAxes: timeR elevationR azimuthR distanceR
# shape = (3, 360, 1324)
# <class 'siphon.cdmr.dataset.Variable'>
# int32 timeR(scanR, radialR)
# 	long_name: time of each ray
# 	units: msecs since 2021-06-26T00:00:00Z
# 	missing_value: -9999
# 	_CoordinateAxisType: Time
# shape = (3, 360)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 elevationR(scanR, radialR)
# 	units: degrees
# 	long_name: elevation angle in degres: 0 = parallel to pedestal base, 90 = perpendicular
# 	missing_value: nan
# 	_CoordinateAxisType: RadialElevation
# shape = (3, 360)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 azimuthR(scanR, radialR)
# 	units: degrees
# 	long_name: azimuth angle in degrees: 0 = true north, 90 = east
# 	missing_value: nan
# 	_CoordinateAxisType: RadialAzimuth
# shape = (3, 360)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 distanceR(gateR)
# 	units: m
# 	long_name: radial distance to start of gate
# 	_CoordinateAxisType: RadialDistance
# shape = 1324
# <class 'siphon.cdmr.dataset.Variable'>
# int32 numRadialsR(scanR)
# 	long_name: number of valid radials in this scan
# shape = 3
# <class 'siphon.cdmr.dataset.Variable'>
# int32 numGatesR(scanR)
# 	long_name: number of valid gates in this scan
# shape = 3
# <class 'siphon.cdmr.dataset.Variable'>
# int8 RadialVelocity_HI(scanV_HI, radialV_HI, gateV_HI)
# 	units: m/s
# 	long_name: Radial Velocity_HI
# 	missing_value: [1 0]
# 	signal_below_threshold: 0
# 	scale_factor: 0.5
# 	add_offset: -64.5
# 	_Unsigned: true
# 	SNR_threshold: 4
# 	range_folding_threshold: 50
# 	_CoordinateAxes: timeV_HI elevationV_HI azimuthV_HI distanceV_HI
# shape = (2, 720, 1192)
# <class 'siphon.cdmr.dataset.Variable'>
# int32 timeV_HI(scanV_HI, radialV_HI)
# 	long_name: time of each ray
# 	units: msecs since 2021-06-26T00:00:00Z
# 	missing_value: -9999
# 	_CoordinateAxisType: Time
# shape = (2, 720)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 elevationV_HI(scanV_HI, radialV_HI)
# 	units: degrees
# 	long_name: elevation angle in degres: 0 = parallel to pedestal base, 90 = perpendicular
# 	missing_value: nan
# 	_CoordinateAxisType: RadialElevation
# shape = (2, 720)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 azimuthV_HI(scanV_HI, radialV_HI)
# 	units: degrees
# 	long_name: azimuth angle in degrees: 0 = true north, 90 = east
# 	missing_value: nan
# 	_CoordinateAxisType: RadialAzimuth
# shape = (2, 720)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 distanceV_HI(gateV_HI)
# 	units: m
# 	long_name: radial distance to start of gate
# 	_CoordinateAxisType: RadialDistance
# shape = 1192
# <class 'siphon.cdmr.dataset.Variable'>
# int32 numRadialsV_HI(scanV_HI)
# 	long_name: number of valid radials in this scan
# shape = 2
# <class 'siphon.cdmr.dataset.Variable'>
# int32 numGatesV_HI(scanV_HI)
# 	long_name: number of valid gates in this scan
# shape = 2
# <class 'siphon.cdmr.dataset.Variable'>
# int8 RadialVelocity(scanV, radialV, gateV)
# 	units: m/s
# 	long_name: Radial Velocity
# 	missing_value: [1 0]
# 	signal_below_threshold: 0
# 	scale_factor: 0.5
# 	add_offset: -64.5
# 	_Unsigned: true
# 	range_folding_threshold: 50
# 	_CoordinateAxes: timeV elevationV azimuthV distanceV
# shape = (3, 360, 1192)
# <class 'siphon.cdmr.dataset.Variable'>
# int32 timeV(scanV, radialV)
# 	long_name: time of each ray
# 	units: msecs since 2021-06-26T00:00:00Z
# 	missing_value: -9999
# 	_CoordinateAxisType: Time
# shape = (3, 360)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 elevationV(scanV, radialV)
# 	units: degrees
# 	long_name: elevation angle in degres: 0 = parallel to pedestal base, 90 = perpendicular
# 	missing_value: nan
# 	_CoordinateAxisType: RadialElevation
# shape = (3, 360)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 azimuthV(scanV, radialV)
# 	units: degrees
# 	long_name: azimuth angle in degrees: 0 = true north, 90 = east
# 	missing_value: nan
# 	_CoordinateAxisType: RadialAzimuth
# shape = (3, 360)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 distanceV(gateV)
# 	units: m
# 	long_name: radial distance to start of gate
# 	_CoordinateAxisType: RadialDistance
# shape = 1192
# <class 'siphon.cdmr.dataset.Variable'>
# int32 numRadialsV(scanV)
# 	long_name: number of valid radials in this scan
# shape = 3
# <class 'siphon.cdmr.dataset.Variable'>
# int32 numGatesV(scanV)
# 	long_name: number of valid gates in this scan
# shape = 3
# <class 'siphon.cdmr.dataset.Variable'>
# int8 SpectrumWidth_HI(scanV_HI, radialV_HI, gateV_HI)
# 	units: m/s
# 	long_name: Radial Spectrum_HI
# 	missing_value: [1 0]
# 	signal_below_threshold: 0
# 	scale_factor: 0.5
# 	add_offset: -64.5
# 	_Unsigned: true
# 	SNR_threshold: 4
# 	range_folding_threshold: 50
# 	_CoordinateAxes: timeV_HI elevationV_HI azimuthV_HI distanceV_HI
# shape = (2, 720, 1192)
# <class 'siphon.cdmr.dataset.Variable'>
# int8 SpectrumWidth(scanV, radialV, gateV)
# 	units: m/s
# 	long_name: Radial Spectrum
# 	missing_value: [1 0]
# 	signal_below_threshold: 0
# 	scale_factor: 0.5
# 	add_offset: -64.5
# 	_Unsigned: true
# 	SNR_threshold: 4
# 	range_folding_threshold: 50
# 	_CoordinateAxes: timeV elevationV azimuthV distanceV
# shape = (3, 360, 1192)
# <class 'siphon.cdmr.dataset.Variable'>
# uint16 DifferentialReflectivity_HI(scanD_HI, radialD_HI, gateD_HI)
# 	units: dBz
# 	long_name: Differential Reflectivity_HI
# 	missing_value: [1 0]
# 	signal_below_threshold: 0
# 	scale_factor: 0.03125
# 	add_offset: -13.0625
# 	_Unsigned: true
# 	SNR_threshold: 4
# 	range_folding_threshold: 50
# 	_CoordinateAxes: timeD_HI elevationD_HI azimuthD_HI distanceD_HI
# shape = (2, 720, 1192)
# <class 'siphon.cdmr.dataset.Variable'>
# int32 timeD_HI(scanD_HI, radialD_HI)
# 	long_name: time of each ray
# 	units: msecs since 2021-06-26T00:00:00Z
# 	missing_value: -9999
# 	_CoordinateAxisType: Time
# shape = (2, 720)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 elevationD_HI(scanD_HI, radialD_HI)
# 	units: degrees
# 	long_name: elevation angle in degres: 0 = parallel to pedestal base, 90 = perpendicular
# 	missing_value: nan
# 	_CoordinateAxisType: RadialElevation
# shape = (2, 720)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 azimuthD_HI(scanD_HI, radialD_HI)
# 	units: degrees
# 	long_name: azimuth angle in degrees: 0 = true north, 90 = east
# 	missing_value: nan
# 	_CoordinateAxisType: RadialAzimuth
# shape = (2, 720)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 distanceD_HI(gateD_HI)
# 	units: m
# 	long_name: radial distance to start of gate
# 	_CoordinateAxisType: RadialDistance
# shape = 1192
# <class 'siphon.cdmr.dataset.Variable'>
# int32 numRadialsD_HI(scanD_HI)
# 	long_name: number of valid radials in this scan
# shape = 2
# <class 'siphon.cdmr.dataset.Variable'>
# int32 numGatesD_HI(scanD_HI)
# 	long_name: number of valid gates in this scan
# shape = 2
# <class 'siphon.cdmr.dataset.Variable'>
# uint16 DifferentialReflectivity(scanD, radialD, gateD)
# 	units: dBz
# 	long_name: Differential Reflectivity
# 	missing_value: [1 0]
# 	signal_below_threshold: 0
# 	scale_factor: 0.03125
# 	add_offset: -13.0625
# 	_Unsigned: true
# 	range_folding_threshold: 50
# 	_CoordinateAxes: timeD elevationD azimuthD distanceD
# shape = (3, 360, 1192)
# <class 'siphon.cdmr.dataset.Variable'>
# int32 timeD(scanD, radialD)
# 	long_name: time of each ray
# 	units: msecs since 2021-06-26T00:00:00Z
# 	missing_value: -9999
# 	_CoordinateAxisType: Time
# shape = (3, 360)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 elevationD(scanD, radialD)
# 	units: degrees
# 	long_name: elevation angle in degres: 0 = parallel to pedestal base, 90 = perpendicular
# 	missing_value: nan
# 	_CoordinateAxisType: RadialElevation
# shape = (3, 360)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 azimuthD(scanD, radialD)
# 	units: degrees
# 	long_name: azimuth angle in degrees: 0 = true north, 90 = east
# 	missing_value: nan
# 	_CoordinateAxisType: RadialAzimuth
# shape = (3, 360)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 distanceD(gateD)
# 	units: m
# 	long_name: radial distance to start of gate
# 	_CoordinateAxisType: RadialDistance
# shape = 1192
# <class 'siphon.cdmr.dataset.Variable'>
# int32 numRadialsD(scanD)
# 	long_name: number of valid radials in this scan
# shape = 3
# <class 'siphon.cdmr.dataset.Variable'>
# int32 numGatesD(scanD)
# 	long_name: number of valid gates in this scan
# shape = 3
# <class 'siphon.cdmr.dataset.Variable'>
# int8 CorrelationCoefficient_HI(scanC_HI, radialC_HI, gateC_HI)
# 	units: N/A
# 	long_name: Correlation Coefficient_HI
# 	missing_value: [1 0]
# 	signal_below_threshold: 0
# 	scale_factor: 0.0033333334140479565
# 	add_offset: 0.2016666680574417
# 	_Unsigned: true
# 	SNR_threshold: 4
# 	range_folding_threshold: 50
# 	_CoordinateAxes: timeC_HI elevationC_HI azimuthC_HI distanceC_HI
# shape = (2, 720, 1192)
# <class 'siphon.cdmr.dataset.Variable'>
# int32 timeC_HI(scanC_HI, radialC_HI)
# 	long_name: time of each ray
# 	units: msecs since 2021-06-26T00:00:00Z
# 	missing_value: -9999
# 	_CoordinateAxisType: Time
# shape = (2, 720)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 elevationC_HI(scanC_HI, radialC_HI)
# 	units: degrees
# 	long_name: elevation angle in degres: 0 = parallel to pedestal base, 90 = perpendicular
# 	missing_value: nan
# 	_CoordinateAxisType: RadialElevation
# shape = (2, 720)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 azimuthC_HI(scanC_HI, radialC_HI)
# 	units: degrees
# 	long_name: azimuth angle in degrees: 0 = true north, 90 = east
# 	missing_value: nan
# 	_CoordinateAxisType: RadialAzimuth
# shape = (2, 720)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 distanceC_HI(gateC_HI)
# 	units: m
# 	long_name: radial distance to start of gate
# 	_CoordinateAxisType: RadialDistance
# shape = 1192
# <class 'siphon.cdmr.dataset.Variable'>
# int32 numRadialsC_HI(scanC_HI)
# 	long_name: number of valid radials in this scan
# shape = 2
# <class 'siphon.cdmr.dataset.Variable'>
# int32 numGatesC_HI(scanC_HI)
# 	long_name: number of valid gates in this scan
# shape = 2
# <class 'siphon.cdmr.dataset.Variable'>
# int8 CorrelationCoefficient(scanC, radialC, gateC)
# 	units: N/A
# 	long_name: Correlation Coefficient
# 	missing_value: [1 0]
# 	signal_below_threshold: 0
# 	scale_factor: 0.0033333334140479565
# 	add_offset: 0.2016666680574417
# 	_Unsigned: true
# 	range_folding_threshold: 50
# 	_CoordinateAxes: timeC elevationC azimuthC distanceC
# shape = (3, 360, 1192)
# <class 'siphon.cdmr.dataset.Variable'>
# int32 timeC(scanC, radialC)
# 	long_name: time of each ray
# 	units: msecs since 2021-06-26T00:00:00Z
# 	missing_value: -9999
# 	_CoordinateAxisType: Time
# shape = (3, 360)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 elevationC(scanC, radialC)
# 	units: degrees
# 	long_name: elevation angle in degres: 0 = parallel to pedestal base, 90 = perpendicular
# 	missing_value: nan
# 	_CoordinateAxisType: RadialElevation
# shape = (3, 360)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 azimuthC(scanC, radialC)
# 	units: degrees
# 	long_name: azimuth angle in degrees: 0 = true north, 90 = east
# 	missing_value: nan
# 	_CoordinateAxisType: RadialAzimuth
# shape = (3, 360)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 distanceC(gateC)
# 	units: m
# 	long_name: radial distance to start of gate
# 	_CoordinateAxisType: RadialDistance
# shape = 1192
# <class 'siphon.cdmr.dataset.Variable'>
# int32 numRadialsC(scanC)
# 	long_name: number of valid radials in this scan
# shape = 3
# <class 'siphon.cdmr.dataset.Variable'>
# int32 numGatesC(scanC)
# 	long_name: number of valid gates in this scan
# shape = 3
# <class 'siphon.cdmr.dataset.Variable'>
# uint16 DifferentialPhase_HI(scanP_HI, radialP_HI, gateP_HI)
# 	units: deg
# 	long_name: Differential Phase_HI
# 	missing_value: [1 0]
# 	signal_below_threshold: 0
# 	scale_factor: 0.35259684920310974
# 	add_offset: -0.7051936984062195
# 	_Unsigned: true
# 	SNR_threshold: 4
# 	range_folding_threshold: 50
# 	_CoordinateAxes: timeP_HI elevationP_HI azimuthP_HI distanceP_HI
# shape = (2, 720, 1192)
# <class 'siphon.cdmr.dataset.Variable'>
# int32 timeP_HI(scanP_HI, radialP_HI)
# 	long_name: time of each ray
# 	units: msecs since 2021-06-26T00:00:00Z
# 	missing_value: -9999
# 	_CoordinateAxisType: Time
# shape = (2, 720)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 elevationP_HI(scanP_HI, radialP_HI)
# 	units: degrees
# 	long_name: elevation angle in degres: 0 = parallel to pedestal base, 90 = perpendicular
# 	missing_value: nan
# 	_CoordinateAxisType: RadialElevation
# shape = (2, 720)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 azimuthP_HI(scanP_HI, radialP_HI)
# 	units: degrees
# 	long_name: azimuth angle in degrees: 0 = true north, 90 = east
# 	missing_value: nan
# 	_CoordinateAxisType: RadialAzimuth
# shape = (2, 720)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 distanceP_HI(gateP_HI)
# 	units: m
# 	long_name: radial distance to start of gate
# 	_CoordinateAxisType: RadialDistance
# shape = 1192
# <class 'siphon.cdmr.dataset.Variable'>
# int32 numRadialsP_HI(scanP_HI)
# 	long_name: number of valid radials in this scan
# shape = 2
# <class 'siphon.cdmr.dataset.Variable'>
# int32 numGatesP_HI(scanP_HI)
# 	long_name: number of valid gates in this scan
# shape = 2
# <class 'siphon.cdmr.dataset.Variable'>
# uint16 DifferentialPhase(scanP, radialP, gateP)
# 	units: deg
# 	long_name: Differential Phase
# 	missing_value: [1 0]
# 	signal_below_threshold: 0
# 	scale_factor: 0.35259684920310974
# 	add_offset: -0.7051936984062195
# 	_Unsigned: true
# 	range_folding_threshold: 50
# 	_CoordinateAxes: timeP elevationP azimuthP distanceP
# shape = (3, 360, 1192)
# <class 'siphon.cdmr.dataset.Variable'>
# int32 timeP(scanP, radialP)
# 	long_name: time of each ray
# 	units: msecs since 2021-06-26T00:00:00Z
# 	missing_value: -9999
# 	_CoordinateAxisType: Time
# shape = (3, 360)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 elevationP(scanP, radialP)
# 	units: degrees
# 	long_name: elevation angle in degres: 0 = parallel to pedestal base, 90 = perpendicular
# 	missing_value: nan
# 	_CoordinateAxisType: RadialElevation
# shape = (3, 360)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 azimuthP(scanP, radialP)
# 	units: degrees
# 	long_name: azimuth angle in degrees: 0 = true north, 90 = east
# 	missing_value: nan
# 	_CoordinateAxisType: RadialAzimuth
# shape = (3, 360)
# <class 'siphon.cdmr.dataset.Variable'>
# float32 distanceP(gateP)
# 	units: m
# 	long_name: radial distance to start of gate
# 	_CoordinateAxisType: RadialDistance
# shape = 1192
# <class 'siphon.cdmr.dataset.Variable'>
# int32 numRadialsP(scanP)
# 	long_name: number of valid radials in this scan
# shape = 3
# <class 'siphon.cdmr.dataset.Variable'>
# int32 numGatesP(scanP)
# 	long_name: number of valid gates in this scan
# shape = 3
# Attributes:
# 	Station: KLVX
# 	StationName: Louisville/Fort Knox,KY,US
# 	StationLatitude: 37.97527777777778
# 	StationLongitude: -85.94388888888889
# 	StationElevationInMeters: 219.0
# 	geospatial_lat_min: 35.27628582090983
# 	geospatial_lat_max: 40.674269734645726
# 	geospatial_lon_min: -89.36780491875585
# 	geospatial_lon_max: -82.51997285902193
# 	Conventions: _Coordinates
# 	format: AR2V0006
# 	cdm_data_type: RADIAL
# 	base_date: 2021-06-26
# 	time_coverage_start: 2021-06-26T13:36:47Z
# 	time_coverage_end: 2021-06-26T13:46:17Z
# 	history: Direct read of Nexrad Level 2 file into CDM
# 	DataType: Radial
# 	Title: Nexrad Level 2 Station KLVX from 2021-06-26T13:36:47Z to 2021-06-26T13:46:17Z
# 	Summary: Weather Surveillance Radar-1988 Doppler (WSR-88D) Level II data are the three meteorological base data quantities: reflectivity, mean radial velocity, and spectrum width.
# 	keywords: WSR-88D; NEXRAD; Radar Level II; reflectivity; mean radial velocity; spectrum width
# 	VolumeCoveragePatternName: 7 elevation scans every 10 mins
# 	VolumeCoveragePattern: 32
# 	HorizontalBeamWidthInDegrees: 1.5

# %%
def raw_to_masked_float(var, data):
    # Values come back signed. If the _Unsigned attribute is set, we need to convert
    # from the range [-127, 128] to [0, 255].
    if var._Unsigned:
        data = data & 255

    # Mask missing points
    data = np.ma.array(data, mask=data==0)

    # Convert to float using the scale and offset
    return data * var.scale_factor + var.add_offset

def polar_to_cartesian(az, rng):
    az_rad = np.deg2rad(az)[:, None]
    x = rng * np.sin(az_rad)
    y = rng * np.cos(az_rad)
    return x, y

# %%
sweep = 0
ref_var = data.variables['Reflectivity_HI']
ref_data = ref_var[sweep]
rng = data.variables['distanceR_HI'][:]
az = data.variables['azimuthR_HI'][sweep]

# %%
ref = raw_to_masked_float(ref_var, ref_data)
x, y = polar_to_cartesian(az, rng)

# %%
ref_norm, ref_cmap = mpplots.ctables.registry.get_with_steps('NWSReflectivity', 5, 5)

# %%
def new_map(fig, lon, lat):
    # Create projection centered on the radar. This allows us to use x
    # and y relative to the radar.
    proj = ccrs.LambertConformal(central_longitude=lon, central_latitude=lat)

    # New axes with the specified projection
    ax = fig.add_axes([0.02, 0.02, 0.96, 0.96], projection=proj)

    # Add coastlines and states
    ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=2)
    ax.add_feature(cfeature.STATES.with_scale('50m'))
    
    return ax

# %%
fig = plt.figure(figsize=(10, 10))
ax = new_map(fig, data.StationLongitude, data.StationLatitude)
ax.pcolormesh(x, y, ref, cmap=ref_cmap, norm=ref_norm, zorder=0)
# Out:
# /Users/isabelle/opt/anaconda3/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py:1597: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   X, Y, C, shading = self._pcolorargs('pcolormesh', *args,

# %%
query = rs.query()
dt = datetime(2012, 10, 29, 15) # Our specified time
query.lonlat_point(-73.687, 41.175).time_range(dt, dt + timedelta(hours=1))
# Out:
# time_start=2012-10-29T15%3A00%3A00&time_end=2012-10-29T16%3A00%3A00&longitude=-73.687&latitude=41.175

# %%
cat = rs.get_catalog(query)
cat.datasets
# Out:
# ['KOKX20121029_150259_V06.gz', 'KOKX20121029_150854_V06.gz', 'KOKX20121029_151451_V06.gz', 'KOKX20121029_152046_V06.gz', 'KOKX20121029_152639_V06.gz', 'KOKX20121029_153234_V06.gz', 'KOKX20121029_153829_V06.gz', 'KOKX20121029_154422_V06.gz', 'KOKX20121029_155017_V06.gz', 'KOKX20121029_155612_V06.gz']

# %%
for gzfile in cat.datasets:
    get_gzip(gzfile)

# %%
ds = cat.datasets[0]
data = ds.remote_access()
fig = plt.figure(figsize=(10, 7.5))
ax = new_map(fig, data.StationLongitude, data.StationLatitude)

# Set limits in lat/lon space
ax.set_extent([-77, -70, 37, 41])

ax.add_feature(cfeature.OCEAN.with_scale('50m'))
ax.add_feature(cfeature.LAND.with_scale('50m'))

# %%
meshes = []
for ds_name in cat.datasets:
    # After looping over the list of sorted datasets, pull the actual Dataset object out
    # of our list of items and access over CDMRemote
    data = cat.datasets[ds_name].remote_access()

    # Pull out the data of interest
    sweep = 0
    rng = data.variables['distanceR_HI'][:]
    az = data.variables['azimuthR_HI'][sweep]
    ref_var = data.variables['Reflectivity_HI']

    # Convert data to float and coordinates to Cartesian
    ref = raw_to_masked_float(ref_var, ref_var[sweep])
    x, y = polar_to_cartesian(az, rng)

    # Plot the data and the timestamp
    mesh = ax.pcolormesh(x, y, ref, cmap=ref_cmap, norm=ref_norm, zorder=0)
    text = ax.text(0.7, 0.02, data.time_coverage_start, transform=ax.transAxes,
                   fontdict={'size':16})
    
    # Collect the things we've plotted so we can animate
    meshes.append((mesh, text))

# %%
# Set up matplotlib to do the conversion to HTML5 video
import matplotlib
matplotlib.rcParams['animation.html'] = 'html5'

# %%
# Create an animation
from matplotlib.animation import ArtistAnimation
ArtistAnimation(fig, meshes)
# Out:
# <video width="720" height="540" controls autoplay loop>
#   <source type="video/mp4" src="...
